# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
df = pd.read_csv('de-bw-freiburg-buergerbefragung_2003_ergebnisse_stadtbezirke_fuer_fritz.csv', encoding='iso-8859-1', sep=';')

# %%
df = df[['Stadtbezirk', 'Zufriedenheit mit dem sozialen Umfeld/Nachbarschaft (Skala von 0=sehr unzufrieden bis 100=sehr zufrieden)']]

# %%
df
# Out:
#                           Stadtbezirk  \
# 0                      Altstadt-Mitte
# 1                       Altstadt-Ring
# 2                             Neuburg
# 3                         Herdern-Süd
# 4                        Herdern-Nord
# 5                           Zähringen
# 6                  Brühl-Güterbahnhof
# 7                            Hochdorf
# 8                             Waldsee
# 9                        Littenweiler
# 10                              Ebnet
# 11                             Kappel
# 12                             Oberau
# 13                         Oberwiehre
# 14                       Mittelwiehre
# 15                   Unterwiehre-Nord
# 16                    Unterwiehre-Süd
# 17                         Günterstal
# 18              Stühlinger-Beurbarung
# 19                Stühlinger-Eschholz
# 20                     Alt-Stühlinger
# 21                      Mooswald-West
# 22                       Mooswald-Ost
# ...

# %%
import shapefile
# read the shapefile
reader = shapefile.Reader("result/stadtbereiche.shp")
fields = reader.fields[1:]
field_names = [field[0] for field in fields]
buffer = []
for sr in reader.shapeRecords():
    atr = dict(zip(field_names, sr.record))
    geom = sr.shape.__geo_interface__
    buffer.append(dict(type="Feature", geometry=geom, properties=atr)) 
   
# write the GeoJSON file
from json import dumps
geojson = open("pyshp-demo.json", "w")
geojson.write(dumps({"type": "FeatureCollection", "features": buffer}, indent=2) + "\n")

geojson.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-b32068306310> in <module>()
#      13 from json import dumps
#      14 geojson = open("pyshp-demo.json", "w")
# ---> 15 geojson.write(dumps({"type": "FeatureCollection", "features": buffer}, indent=2) + "\n")
#      16
#      17 geojson.close()
#
# /usr/lib/python3.5/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     235         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     236         separators=separators, default=default, sort_keys=sort_keys,
# --> 237         **kw).encode(obj)
#     238
#     239
#
# /usr/lib/python3.5/json/encoder.py in encode(self, o)
#     198         chunks = self.iterencode(o, _one_shot=True)
#     199         if not isinstance(chunks, (list, tuple)):
# ...
